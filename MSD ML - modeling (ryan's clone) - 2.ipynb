# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from matplotlib import pyplot
#import s3fs
import io
# import tkinter as tk
# from turtle import clear

from io import StringIO,BytesIO 
#import boto3
#import pyarrow as pa
#import pyarrow.parquet as pq

# %%
#import xgboost as xgb
from sklearn.model_selection import train_test_split
#from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_percentage_error
# ImportError: cannot import name 'mean_absolute_percentage_error' from 'sklearn.metrics' (c:\Users\Rangl\Anaconda3\lib\site-packages\sklearn\metrics\__init__.py)
from sklearn.preprocessing import MinMaxScaler

# %%
#Creating Session With Boto3 Uipath.
  #session = boto3.Session(
  #aws_access_key_id='AKIARNAINAMKXF5JQ3I4',
  #aws_secret_access_key='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'
  #)
  #session = boto3.Session(
  #aws_access_key_id='AKIARNAINAMKTJVU7ZQZ',
  #aws_secret_access_key='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')

#Creating S3 Resource From the Session.
  #s3 = session.resource('s3')


  #local_file_name = 'uipath_test'
  #remote_file_name = 'uipath_test.parquet'


# #convert dataframe to parquet format
  # parquet_table = pa.Table.from_pandas(df)
  # pq.write_table(parquet_table, local_file_name)
  # #df.to_parquet("C:\\Temp\\FilesHeader.parquet")
  # #upload the parquet file to aws
  # s3 = boto3.client('s3',region_name="us-east-1",aws_access_key_id='AKIARNAINAMKTJVU7ZQZ',
  # aws_secret_access_key='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')
  # s3.upload_file(local_file_name, 'tfsdl-aigbi-test', remote_file_name)

# %%
#Read the parquet file
  # buffer = io.BytesIO()
  # s3 = boto3.resource('s3',
  # aws_access_key_id='AKIARNAINAMKXF5JQ3I4',
  # aws_secret_access_key='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'
  # )
  # object = s3.Object('tfsdl-corp-uipath-test',remote_file_name)
  # object.download_fileobj(buffer)
  # df1 = pd.read_parquet(buffer)

  # print(df1.head())

# %%
'''
buffer = io.BytesIO()
s3 = boto3.resource('s3',
                    aws_access_key_id='AKIAV6YS7MC5IT4TN475',
                    aws_secret_access_key='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',
                    region_name='us-east-1'
                   )
'''
#session = boto3.Session( 


#-- original Manthan keys
#aws_access_key_id='AKIARNAINAMKTJVU7ZQZ',
#aws_secret_access_key='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')

#-- parquet keys
#aws_access_key_id='AKIARNAINAMKXF5JQ3I4', # parquet key
#aws_secret_access_key='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') # parquet key

#Creating S3 Resource From the Session.

#local_file_name = 'data_all.csv'
#remote_file_name = 'data_all.csv'

#object = s3.Object('tfsdl-aigbi-test', remote_file_name)
#object.download_fileobj(buffer)
#data_all = pd.read_csv(buffer)
# Out:
# "\nbuffer = io.BytesIO()\ns3 = boto3.resource('s3',\n                    aws_access_key_id='AKIAV6YS7MC5IT4TN475',\n                    aws_secret_access_key='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',\n                    region_name='us-east-1'\n                   )\n"

# %%
# this will only work on work pc
# buffer.getvalue()
'''
data_all = spark.read.csv("s3://tfsdl-aigbi-test/FilesHeader1.csv", header=True)
data_all = data_all.toPandas()
df=spark.read.option("header","true").csv("s3://tfsdl-aigbi-test/FilesHeader1.csv")
'''
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
import os

#// get current dir
#os.getcwd()
#'c:\\Users\\Rangl\\OneDrive\\Programming\\Python\\TFS_Machine_Learning'
fpath = r'c:\\Users\\Rangl\\OneDrive\\Programming\\Python\\TFS_Machine_Learning'

#// list all files
#os.listdir(fpath)

items = os.listdir(".")

newlist = []
for names in items:
    if names.endswith(".txt"):
        newlist.append(names)
newlist
# Out:
# ['09_17_2022data_all.txt', 'Factory D4014HT300.txt']

# %%
raw_data_file_target = '09_17_2022data_all.txt'

df = pd.read_csv('09_17_2022data_all.txt')
df.head()
# Out:
# c:\Users\Rangl\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                                             FileName        LastWriteTime  \
# 0  C:\Temp\FactoryD3201HT300_17\Test\Factory D401...  07/17/2022 14:47:20
# 1  C:\Temp\FactoryD3201HT300_17\Test\Factory D401...  07/17/2022 14:47:20
# 2  C:\Temp\FactoryD3201HT300_17\Test\Factory D401...  07/17/2022 14:47:20
# 3  C:\Temp\FactoryD3201HT300_17\Test\Factory D401...  07/17/2022 14:47:20
# 4  C:\Temp\FactoryD3201HT300_17\Test\Factory D401...  07/17/2022 14:47:20
#
#               Header_1       Header_2           Header_3 Header_4  \
# 0  MdlMonochromatorMgr  Monochromator  CalculatedOffsets      NaN
# 1  MdlMonochromatorMgr  Monochromator  CalculatedOffsets      NaN
# 2  MdlMonochromatorMgr  Monochromator  CalculatedOffsets      NaN
# ...

# %%
df.shape
#(1524519, 8)
# Out:
# (1524519, 8)

# %%
#df.describe()
df.dtypes
# Out:
# FileName         object
# LastWriteTime    object
# Header_1         object
# Header_2         object
# Header_3         object
# Header_4         object
# Header_5         object
# Value            object
# dtype: object

# %%
dfa = df[(~df['Value'].str.contains("x|,", na=False))] #df['Col'].str.contains('|'.join(['x', ',']]))
dfa
# Out:
#                                                   FileName  \
# 0        C:\Temp\FactoryD3201HT300_17\Test\Factory D401...
# 1        C:\Temp\FactoryD3201HT300_17\Test\Factory D401...
# 2        C:\Temp\FactoryD3201HT300_17\Test\Factory D401...
# 3        C:\Temp\FactoryD3201HT300_17\Test\Factory D401...
# 4        C:\Temp\FactoryD3201HT300_17\Test\Factory D401...
# ...                                                    ...
# 1524514  C:\Temp\FactoryD3201HT300_17\Test\FactoryD4235...
# 1524515  C:\Temp\FactoryD3201HT300_17\Test\FactoryD4235...
# 1524516  C:\Temp\FactoryD3201HT300_17\Test\FactoryD4235...
# 1524517  C:\Temp\FactoryD3201HT300_17\Test\FactoryD4235...
# 1524518  C:\Temp\FactoryD3201HT300_17\Test\FactoryD4235...
#
#                LastWriteTime             Header_1                 Header_2  \
# 0        07/17/2022 14:47:20  MdlMonochromatorMgr            Monochromator
# 1        07/17/2022 14:47:20  MdlMonochromatorMgr            Monochromator
# ...

# %%
 len(df.index) - len(dfa.index) # 8112 rows drops
# Out:
# 8112

# %%
dfa.columns
# ['FileName', 'LastWriteTime', 'Header_1', 'Header_2', 'Header_3',
#        'Header_4', 'Header_5', 'Value'],
# Out:
# Index(['FileName', 'LastWriteTime', 'Header_1', 'Header_2', 'Header_3',
#        'Header_4', 'Header_5', 'Value'],
#       dtype='object')

# %%
dfa['FileName'].str.split('\\', expand=True)
# split column and add new columns to df
#dfa[['Street', 'City', 'State']] = dfa['FileName'].str.split('\\', expand=True)

# display the dataframe
#dfa
# Out:
#           0     1                     2     3                          4
# 0        C:  Temp  FactoryD3201HT300_17  Test     Factory D4014HT300.alg
# 1        C:  Temp  FactoryD3201HT300_17  Test     Factory D4014HT300.alg
# 2        C:  Temp  FactoryD3201HT300_17  Test     Factory D4014HT300.alg
# 3        C:  Temp  FactoryD3201HT300_17  Test     Factory D4014HT300.alg
# 4        C:  Temp  FactoryD3201HT300_17  Test     Factory D4014HT300.alg
# ...      ..   ...                   ...   ...                        ...
# 1524514  C:  Temp  FactoryD3201HT300_17  Test  FactoryD4235HT300_401.alg
# 1524515  C:  Temp  FactoryD3201HT300_17  Test  FactoryD4235HT300_401.alg
# 1524516  C:  Temp  FactoryD3201HT300_17  Test  FactoryD4235HT300_401.alg
# 1524517  C:  Temp  FactoryD3201HT300_17  Test  FactoryD4235HT300_401.alg
# 1524518  C:  Temp  FactoryD3201HT300_17  Test  FactoryD4235HT300_401.alg
#
# [1516407 rows x 5 columns]

# %%
# custom number of splits
dfa['FileName'].str.split('\\', n=3, expand=True)
# Out:
#           0     1                     2                               3
# 0        C:  Temp  FactoryD3201HT300_17     Test\Factory D4014HT300.alg
# 1        C:  Temp  FactoryD3201HT300_17     Test\Factory D4014HT300.alg
# 2        C:  Temp  FactoryD3201HT300_17     Test\Factory D4014HT300.alg
# 3        C:  Temp  FactoryD3201HT300_17     Test\Factory D4014HT300.alg
# 4        C:  Temp  FactoryD3201HT300_17     Test\Factory D4014HT300.alg
# ...      ..   ...                   ...                             ...
# 1524514  C:  Temp  FactoryD3201HT300_17  Test\FactoryD4235HT300_401.alg
# 1524515  C:  Temp  FactoryD3201HT300_17  Test\FactoryD4235HT300_401.alg
# 1524516  C:  Temp  FactoryD3201HT300_17  Test\FactoryD4235HT300_401.alg
# 1524517  C:  Temp  FactoryD3201HT300_17  Test\FactoryD4235HT300_401.alg
# 1524518  C:  Temp  FactoryD3201HT300_17  Test\FactoryD4235HT300_401.alg
#
# [1516407 rows x 4 columns]

# %%
dfa[['FN_1', 'FN_2','FN_3','FN_4',]] = dfa['FileName'].str.split('\\', n=3, expand=True)
dfa
# Out:
# c:\Users\Rangl\Anaconda3\lib\site-packages\pandas\core\frame.py:3494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
#                                                   FileName  \
# 0        C:\Temp\FactoryD3201HT300_17\Test\Factory D401...
# 1        C:\Temp\FactoryD3201HT300_17\Test\Factory D401...
# 2        C:\Temp\FactoryD3201HT300_17\Test\Factory D401...
# 3        C:\Temp\FactoryD3201HT300_17\Test\Factory D401...
# 4        C:\Temp\FactoryD3201HT300_17\Test\Factory D401...
# ...                                                    ...
# 1524514  C:\Temp\FactoryD3201HT300_17\Test\FactoryD4235...
# 1524515  C:\Temp\FactoryD3201HT300_17\Test\FactoryD4235...
# ...

# %%
dfa2 = dfa.drop(['FN_1','FN_2', 'FN_4','LastWriteTime'], axis=1)
dfa2.rename({'FN_3': 'Machine'}, axis=1, inplace=True)
#dfa2.str.cat(dfa2[['Header_1', 'Header_2', 'Header_3', 'Header_4', 'Header_5']], sep='.')
dfa2.head()
# Out:
#                                             FileName             Header_1  \
# 0  C:\Temp\FactoryD3201HT300_17\Test\Factory D401...  MdlMonochromatorMgr
# 1  C:\Temp\FactoryD3201HT300_17\Test\Factory D401...  MdlMonochromatorMgr
# 2  C:\Temp\FactoryD3201HT300_17\Test\Factory D401...  MdlMonochromatorMgr
# 3  C:\Temp\FactoryD3201HT300_17\Test\Factory D401...  MdlMonochromatorMgr
# 4  C:\Temp\FactoryD3201HT300_17\Test\Factory D401...  MdlMonochromatorMgr
#
#         Header_2           Header_3 Header_4                         Header_5  \
# 0  Monochromator  CalculatedOffsets      NaN      ShiftlessCorrection_dB_dE2x
# 1  Monochromator  CalculatedOffsets      NaN      ShiftlessCorrection_dB_dE2y
# 2  Monochromator  CalculatedOffsets      NaN    ShiftlessCorrection_dE1y_dE2x
# 3  Monochromator  CalculatedOffsets      NaN    ShiftlessCorrection_dE1y_dE2y
# 4  Monochromator  CalculatedOffsets      NaN  ShiftlessCorrection_dB_dGunlens
#
#                    Value               Machine
# ...

# %%
#dfa2['FeatureName'] = dfa2[['Header_1', 'Header_2', 'Header_3', 'Header_4', 'Header_5']].agg('.'.join, axis=1)
dfa2['FeatureName'] = dfa2['Header_1'].map(str) +'.'+ dfa2['Header_2'].map(str) +'.'+ dfa2['Header_3'].map(str) +'.'+ dfa2['Header_4'].map(str) +'.'+ dfa2['Header_5'].map(str) #.agg('.'.join, axis=1)
dfa2
# Out:
#                                                   FileName  \
# 0        C:\Temp\FactoryD3201HT300_17\Test\Factory D401...
# 1        C:\Temp\FactoryD3201HT300_17\Test\Factory D401...
# 2        C:\Temp\FactoryD3201HT300_17\Test\Factory D401...
# 3        C:\Temp\FactoryD3201HT300_17\Test\Factory D401...
# 4        C:\Temp\FactoryD3201HT300_17\Test\Factory D401...
# ...                                                    ...
# 1524514  C:\Temp\FactoryD3201HT300_17\Test\FactoryD4235...
# 1524515  C:\Temp\FactoryD3201HT300_17\Test\FactoryD4235...
# 1524516  C:\Temp\FactoryD3201HT300_17\Test\FactoryD4235...
# 1524517  C:\Temp\FactoryD3201HT300_17\Test\FactoryD4235...
# 1524518  C:\Temp\FactoryD3201HT300_17\Test\FactoryD4235...
#
#                     Header_1                 Header_2           Header_3  \
# 0        MdlMonochromatorMgr            Monochromator  CalculatedOffsets
# 1        MdlMonochromatorMgr            Monochromator  CalculatedOffsets
# ...

# %%
#dfa[['FN_1', 'FN_2','FN_3','FN_4',]] = 
dfa2['FileName'].str.rsplit('\\', n=3, expand=True)
#dfa

# new dataframe
#dfa3 = dfa2[['', '']]
# Out:
#                                     0     1                          2
# 0        C:\Temp\FactoryD3201HT300_17  Test     Factory D4014HT300.alg
# 1        C:\Temp\FactoryD3201HT300_17  Test     Factory D4014HT300.alg
# 2        C:\Temp\FactoryD3201HT300_17  Test     Factory D4014HT300.alg
# 3        C:\Temp\FactoryD3201HT300_17  Test     Factory D4014HT300.alg
# 4        C:\Temp\FactoryD3201HT300_17  Test     Factory D4014HT300.alg
# ...                               ...   ...                        ...
# 1524514  C:\Temp\FactoryD3201HT300_17  Test  FactoryD4235HT300_401.alg
# 1524515  C:\Temp\FactoryD3201HT300_17  Test  FactoryD4235HT300_401.alg
# 1524516  C:\Temp\FactoryD3201HT300_17  Test  FactoryD4235HT300_401.alg
# 1524517  C:\Temp\FactoryD3201HT300_17  Test  FactoryD4235HT300_401.alg
# 1524518  C:\Temp\FactoryD3201HT300_17  Test  FactoryD4235HT300_401.alg
#
# [1516407 rows x 3 columns]

# %%
# df=data_all.drop(['Align_BS_BeamLorentz_parallelxlor_x',
#        'Align_BS_BeamLorentz_parallelxlor_y', #        'Align_BS_BeamLorentz_probexlor_x', 'Align_BS_BeamLorentz_probexlor_y','Align_BT_BeamLorentz_parallelxlor_x',
#        'Align_BT_BeamLorentz_parallelxlor_y', #        'Align_BT_BeamLorentz_probexlor_x', 'Align_BT_BeamLorentz_probexlor_y','Align_DS_EftemLM_LMxstereoxnolor_x',
#        'Align_DS_EftemLM_LMxstereoxnolor_y', #        'Align_DS_EftemLorentz_stereoxlor_x',
#        'Align_DS_EftemLorentz_stereoxlor_y', #        'Align_DS_EftemMicroProbe_uPxHMxstereoxnolor_x',
#        'Align_DS_EftemMicroProbe_uPxHMxstereoxnolor_y', #        'Align_DS_EftemNanoProbe_nPxHMxstereoxnolor_x',
#        'Align_DS_EftemNanoProbe_nPxHMxstereoxnolor_y', #        'Align_DS_ImageLM_LMxzoomxnolor_x', 'Align_DS_ImageLM_LMxzoomxnolor_y',
#        'Align_DS_ImageLorentz_zoomxlor_x', 'Align_DS_ImageLorentz_zoomxlor_y', #        'Align_DS_ImageMicroProbe_uPxHMxzoomxnolor_x',
#        'Align_DS_ImageMicroProbe_uPxHMxzoomxnolor_y', #        'Align_DS_ImageNanoProbe_nPxHMxzoomxnolor_x',
#        'Align_DS_ImageNanoProbe_nPxHMxzoomxnolor_y', 'Align_IS_EftemLM_LMxstereoxnolor_x',
#        'Align_IS_EftemLM_LMxstereoxnolor_y', #        'Align_IS_EftemLorentz_stereoxlor_x',
#        'Align_IS_EftemLorentz_stereoxlor_y', #        'Align_IS_EftemMicroProbe_HMxstereoxnolor_x',
#        'Align_IS_EftemMicroProbe_HMxstereoxnolor_y', #        'Align_IS_ImageLM_LMxzoomxnolor_x', 'Align_IS_ImageLM_LMxzoomxnolor_y',
#        'Align_IS_ImageLorentz_zoomxlor_x', 'Align_IS_ImageLorentz_zoomxlor_y', #        'Align_IS_ImageMicroProbe_HMxzoomxnolor_x',
#        'Align_IS_ImageMicroProbe_HMxzoomxnolor_y'],axis=1) 
'''
df=data_all.drop(["Align_DS_EftemLorentz_stereoxlor_x",                  
    "Align_IS_EftemLorentz_stereoxlor_y",
    "Align_IS_EftemLorentz_stereoxlor_x",
    "Align_DS_EftemLorentz_stereoxlor_y",
    "Align_BS_BeamLorentz_parallelxlor_x",
    "Align_BS_BeamLorentz_parallelxlor_y",
    "Align_BS_BeamLorentz_probexlor_x",
    "Align_BS_BeamLorentz_probexlor_y",
    "Align_BT_BeamLorentz_probexlor_y",
    "Align_BT_BeamLorentz_probexlor_x",
    "Align_BT_BeamLorentz_parallelxlor_y",
    "Align_BT_BeamLorentz_parallelxlor_x",
    "Align_IS_ImageLorentz_zoomxlor_y",
    "Align_DS_ImageLorentz_zoomxlor_x",
    "Align_DS_ImageLorentz_zoomxlor_y",
    "Align_IS_ImageLorentz_zoomxlor_x",
    "Align_DS_EftemNanoProbe_nPxHMxstereoxnolor_y",
    "Align_DS_EftemNanoProbe_nPxHMxstereoxnolor_x",
    "Align_DS_EftemMicroProbe_uPxHMxstereoxnolor_y",
    "Align_DS_EftemMicroProbe_uPxHMxstereoxnolor_x",
    "Align_IS_EftemLM_LMxstereoxnolor_x",
    "Align_IS_EftemLM_LMxstereoxnolor_y",
    "Align_IS_EftemMicroProbe_HMxstereoxnolor_x",
    "Align_IS_EftemMicroProbe_HMxstereoxnolor_y",
    "Align_DS_EftemLM_LMxstereoxnolor_y",
    "Align_DS_EftemLM_LMxstereoxnolor_x"]
    ,axis=1)
    '''

# %%
df.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>path</th>
#       <th>Align_BS_BeamLM_LMxparallelxnolor_x</th>
#       <th>Align_BS_BeamLM_LMxparallelxnolor_y</th>
#       <th>Align_BS_BeamLM_LMxprobexnolor_x</th>
#       <th>Align_BS_BeamLM_LMxprobexnolor_y</th>
#       <th>Align_BS_BeamMicroProbe_uPxHMxparallelxnolor_x</th>
#       <th>Align_BS_BeamMicroProbe_uPxHMxparallelxnolor_y</th>
#       <th>Align_BS_BeamMicroProbe_uPxHMxprobexnolor_x</th>
#       <th>Align_BS_BeamMicroProbe_uPxHMxprobexnolor_y</th>
#       <th>Align_BS_BeamNanoProbe_nPxHMxparallelxnolor_x</th>
#       <th>...</th>
#       <th>Align_DS_ImageNanoProbe_nPxHMxzoomxnolor_x</th>
# ...

# %%
df['path']=df['path'].str.rsplit("\\").str[-1]

# %%
# df=df.drop_duplicates(subset=["path"])

# %%
df= df.dropna()

# %%
len(df)
# Out:
# Out[12]: 771

# %%
df.to_csv("df.csv")

# %%
df.columns

# %%
df_x=df[[ 'Align_BS_BeamLM_LMxparallelxnolor_x',
       'Align_BS_BeamLM_LMxparallelxnolor_y',
       'Align_BS_BeamLM_LMxprobexnolor_x', 'Align_BS_BeamLM_LMxprobexnolor_y',
       'Align_BS_BeamMicroProbe_uPxHMxparallelxnolor_x',
       'Align_BS_BeamMicroProbe_uPxHMxparallelxnolor_y',
       'Align_BS_BeamMicroProbe_uPxHMxprobexnolor_x',
       'Align_BS_BeamMicroProbe_uPxHMxprobexnolor_y',
       'Align_BT_BeamLM_LMxparallelxnolor_x',
       'Align_BT_BeamLM_LMxparallelxnolor_y',
       'Align_BT_BeamLM_LMxprobexnolor_x', 'Align_BT_BeamLM_LMxprobexnolor_y',
       'Align_BT_BeamMicroProbe_uPxHMxparallelxnolor_x',
       'Align_BT_BeamMicroProbe_uPxHMxparallelxnolor_y',
       'Align_BT_BeamMicroProbe_uPxHMxprobexnolor_x',
       'Align_BT_BeamMicroProbe_uPxHMxprobexnolor_y', 'Align_CS_Gun_gen_x',
       'Align_CS_Gun_gen_y', 'Align_CT_Gun_gen_x', 'Align_CT_Gun_gen_y',
       'Align_DS_ImageLM_LMxzoomxnolor_x', 'Align_DS_ImageLM_LMxzoomxnolor_y',
       'Align_DS_ImageMicroProbe_uPxHMxzoomxnolor_x',
       'Align_DS_ImageMicroProbe_uPxHMxzoomxnolor_y',
       'Align_DS_ImageNanoProbe_nPxHMxzoomxnolor_x',
       'Align_DS_ImageNanoProbe_nPxHMxzoomxnolor_y', 'Align_GS_Gun_gen_x',
       'Align_GS_Gun_gen_y', 'Align_GT_Gun_gen_x', 'Align_GT_Gun_gen_y',
       'Align_IS_ImageLM_LMxzoomxnolor_x', 'Align_IS_ImageLM_LMxzoomxnolor_y',
       'Align_IS_ImageMicroProbe_HMxzoomxnolor_x',
       'Align_IS_ImageMicroProbe_HMxzoomxnolor_y']]

# df_x=df[[ 'Align_BS_BeamLM_LMxparallelxnolor_x',
#        'Align_BS_BeamLM_LMxparallelxnolor_y',
#        'Align_BS_BeamLM_LMxprobexnolor_x', 'Align_BS_BeamLM_LMxprobexnolor_y',
#        'Align_BS_BeamMicroProbe_uPxHMxparallelxnolor_x',
#        'Align_BS_BeamMicroProbe_uPxHMxparallelxnolor_y',
#        'Align_BS_BeamMicroProbe_uPxHMxprobexnolor_x',
#        'Align_BS_BeamMicroProbe_uPxHMxprobexnolor_y',
#        'Align_BT_BeamLM_LMxparallelxnolor_x',
#        'Align_BT_BeamLM_LMxparallelxnolor_y',
#        'Align_BT_BeamLM_LMxprobexnolor_x', 'Align_BT_BeamLM_LMxprobexnolor_y',
#        'Align_BT_BeamMicroProbe_uPxHMxparallelxnolor_x',
#        'Align_BT_BeamMicroProbe_uPxHMxparallelxnolor_y',
#        'Align_BT_BeamMicroProbe_uPxHMxprobexnolor_x',
#        'Align_BT_BeamMicroProbe_uPxHMxprobexnolor_y','Align_CS_Gun_gen_x',
#        'Align_CS_Gun_gen_y', 'Align_CT_Gun_gen_x', 'Align_CT_Gun_gen_y',
#        'Align_GS_Gun_gen_x', 'Align_GS_Gun_gen_y', 'Align_GT_Gun_gen_x',
#        'Align_GT_Gun_gen_y']]

# %%
len(df_x.columns)
# Out:
# Out[16]: 34

# %%
df_y=df[["Align_BS_BeamNanoProbe_nPxHMxparallelxnolor_y"]]
# 'Align_BS_BeamNanoProbe_nPxHMxparallelxnolor_x',
# 'Align_BS_BeamNanoProbe_nPxHMxparallelxnolor_y',
# 'Align_BS_BeamNanoProbe_nPxHMxprobexnolor_x',
# 'Align_BS_BeamNanoProbe_nPxHMxprobexnolor_y',
# 'Align_BT_BeamNanoProbe_nPxHMxparallelxnolor_x',
# 'Align_BT_BeamNanoProbe_nPxHMxparallelxnolor_y',
# 'Align_BT_BeamNanoProbe_nPxHMxprobexnolor_x',
# 'Align_BT_BeamNanoProbe_nPxHMxprobexnolor_y']

# %%
df_x.describe()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Align_BS_BeamLM_LMxparallelxnolor_x</th>
#       <th>Align_BS_BeamLM_LMxparallelxnolor_y</th>
#       <th>Align_BS_BeamLM_LMxprobexnolor_x</th>
#       <th>Align_BS_BeamLM_LMxprobexnolor_y</th>
#       <th>Align_BS_BeamMicroProbe_uPxHMxparallelxnolor_x</th>
#       <th>Align_BS_BeamMicroProbe_uPxHMxparallelxnolor_y</th>
#       <th>Align_BS_BeamMicroProbe_uPxHMxprobexnolor_x</th>
#       <th>Align_BS_BeamMicroProbe_uPxHMxprobexnolor_y</th>
#       <th>Align_BT_BeamLM_LMxparallelxnolor_x</th>
#       <th>Align_BT_BeamLM_LMxparallelxnolor_y</th>
#       <th>...</th>
# ...

# %%
df_y.describe()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Align_BS_BeamNanoProbe_nPxHMxparallelxnolor_y</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>771.000000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>0.012096</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>0.120667</td>
#     </tr>
#     <tr>
#       <th>min</th>
#       <td>-0.477280</td>
#     </tr>
#     <tr>
#       <th>25%</th>
#       <td>-0.048771</td>
#     </tr>
#     <tr>
#       <th>50%</th>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <th>75%</th>
#       <td>0.073937</td>
#     </tr>
#     <tr>
#       <th>max</th>
# ...

# %%
len(df_y)
# Out:
# Out[20]: 771

# %%
(df_y==0).sum()
# Out:
# Out[21]: Align_BS_BeamNanoProbe_nPxHMxparallelxnolor_y    33
# dtype: int64

# %%
df_x.drop(df_x.columns[feat_ind],axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-02378efd07a8> in <module>
# ----> 1 df_x.drop(df_x.columns[feat_ind],axis=1,inplace=True)
#
# NameError: name 'feat_ind' is not defined

# %%
print(df_x)
# Out:
#      Align_BS_BeamLM_LMxparallelxnolor_x  Align_BS_BeamLM_LMxparallelxnolor_y  \
# 0                               0.086376                            -0.099261
# 65                             -0.497264                             0.471986
# 66                             -0.497264                             0.471986
# 67                             -0.497264                             0.471986
# 68                             -0.017968                            -0.008138
# ..                                   ...                                  ...
# 851                            -0.010565                             0.035450
# 852                            -0.160285                             0.112062
# 853                            -0.160285                             0.112062
# 854                            -0.018015                            -0.014736
# 855                             0.053667                             0.116110
#
# ...

# %%
print(df_y) #y to be predicted
# Out:
#      Align_BS_BeamNanoProbe_nPxHMxparallelxnolor_y
# 0                                        -0.043689
# 65                                        0.304018
# 66                                        0.304018
# 67                                        0.304018
# 68                                       -0.063254
# ..                                             ...
# 851                                       0.074014
# 852                                       0.004479
# 853                                       0.004479
# 854                                      -0.085118
# 855                                       0.091430
#
# [771 rows x 1 columns]

# %%
scaler = MinMaxScaler()
# df_norm = pd.DataFrame(scaler.fit_transform(df_x), columns=df_x.columns)
df_norm=df_x

# %%
train_X, test_X, train_y, test_y = train_test_split(df_norm,df_y,
                      test_size = 0.3, random_state = 123)

# %%
xgb_r = xgb.XGBRegressor(objective ='reg:squarederror',
#                                        n_estimators = 100, max_depth=10,max_leaves=10,learning_rate=0.1,
                         seed = 123,verbosity=1)

# %%
# Fitting the model
xgb_r.fit(train_X, train_y)
  
# Predict the model
pred = xgb_r.predict(test_X)
  
# RMSE Computation
rmse = np.sqrt(mean_squared_error(test_y,pred))
r2score = r2_score(test_y,pred)
mape =mean_absolute_percentage_error(test_y,pred)
print("RMSE : % f" %(rmse), "\t MAPE : %f" %(mape), "\t R2_score : %f" %(r2score))
# Out:
# RMSE :  0.075961 	 MAPE : 2268660711709.940918 	 R2_score : 0.595965

# %%
n = len(train_X)
p = len(train_X.columns)
# n = number of observation, p = number of features

# %%
Adj_r2 = 1-(1-r2score)*(n-1)/(n-p-1)
print("\tAdjusted R2_score : %f" %(Adj_r2))
# Out:
# 	Adjusted R2_score : 0.568709

# %%
xgb_r
# Out:
# Out[30]: XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=100, n_jobs=12, num_parallel_tree=1, random_state=123,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=123,
#              subsample=1, tree_method='exact', validate_parameters=1,
#              verbosity=1)

# %%
imp = pd.DataFrame(xgb_r.feature_importances_)

# %%
imp.sort_values(by=0,ascending=False)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>5</th>
#       <td>0.376554</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>0.077634</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>0.041806</td>
#     </tr>
#     <tr>
#       <th>33</th>
#       <td>0.041505</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>0.040096</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>0.039543</td>
#     </tr>
#     <tr>
#       <th>31</th>
#       <td>0.030780</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>0.028276</td>
#     </tr>
#     <tr>
# ...

# %%
xgb.plot_importance(xgb_r)
pyplot.show()

# %%
n=(imp[imp[0]<0.02])
print(n)
# len(imp[imp[0]<0.01])
# Out:
#            0
# 0   0.011035
# 1   0.011215
# 2   0.007469
# 4   0.017076
# 6   0.019459
# 8   0.004776
# 9   0.012816
# 10  0.008180
# 12  0.006727
# 14  0.001832
# 15  0.007724
# 16  0.008956
# 17  0.014678
# 20  0.009692
# 21  0.011860
# 22  0.019224
# 23  0.018829
# 24  0.011399
# 25  0.013891
# 26  0.010721
# 27  0.008179
# 30  0.014313
# 32  0.006479

# %%
feat_ind=n.index

# %%
test_y.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Align_BT_BeamNanoProbe_nPxHMxparallelxnolor_x</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>327</th>
#       <td>-0.062000</td>
#     </tr>
#     <tr>
#       <th>294</th>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <th>117</th>
#       <td>0.021900</td>
#     </tr>
#     <tr>
#       <th>311</th>
#       <td>0.056500</td>
#     </tr>
#     <tr>
#       <th>608</th>
#       <td>-0.018782</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
yhat = xgb_r.predict(test_X)

# %%
print(yhat.astype('str'))
# Out:
# ['-0.026004659' '-0.00015479361' '-0.0054767644' '-0.002555385'
#  '-0.019741494' '-0.028794391' '-0.0209884' '0.00090668723'
#  '-0.00027025302' '-0.048884034' '-0.052006956' '-0.022424348'
#  '-0.0184696' '-0.01695428' '0.1787407' '-0.08599468' '-1.2985846e-05'
#  '-0.025760787' '-1.2985846e-05' '-0.021527765' '0.007898027'
#  '-0.025332998' '0.0059165736' '-0.026661707' '-0.052006956'
#  '-0.017382424' '0.015525683' '-0.010286856' '-0.05885966' '0.03511317'
#  '0.076831765' '-0.00012829811' '-0.10861498' '-0.041545853'
#  '-6.438821e-05' '-0.0024526897' '0.016550569' '0.06935259' '0.29341274'
#  '0.016613102' '0.05383452' '-0.00014040727' '-0.012150843' '0.0003909965'
#  '-0.008621224' '0.00703409' '0.012213973' '-0.06912607' '-0.012908238'
#  '-0.0209884' '-0.021129051' '-0.028321069' '0.1872221' '0.076831765'
#  '0.010142248' '0.036431156' '-0.16867642' '0.12929599' '-0.033991385'
#  '0.03664017' '-0.029279623' '-0.033967793' '-0.022424348' '0.10247894'
# ...

# %%
model.fit(train_X, train_y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-92379a943613> in <module>
# ----> 1 model.fit(train_X, train_y)
#
# NameError: name 'model' is not defined

# %%
error = mean_squared_error(yhat,test_y)
print(error)
# Out:
# 0.003785344450857532

# %%
df1['Align_BS_BeamNanoProbe_nPxHMxparallelxnolor_x'].mean()
# Out:
# Out[90]: -0.00741180179657387

# %%
100*(error/test_y.min())
# Out:
# Out[339]: Align_BT_BeamNanoProbe_nPxHMxparallelxnolor_y   -1.319586
# dtype: float64
